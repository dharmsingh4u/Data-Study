# %%
from typing import Literal, Optional
from langgraph.graph import StateGraph, MessagesState, START, END
from IPython.display import Image, display
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.checkpoint.memory import MemorySaver
from pprint import pprint
import sys
sys.path.insert(1, r'D:\Notebooks\LLM\env')
#sys.path.insert(2, r'C:\Users\Dharmendra Vartika\LLM\langchain_document_loader')
from enviorment import load_env
load_env()

# --- Model Definition ---
# OpenAI API key configured in .env file
model = ChatOpenAI(model="gpt-4o-mini")


# --- Graph State Definition ---
class DraftReviewState(MessagesState):
    human_request: str
    human_comment: Optional[str]
    status: Literal["approved", "feedback"]
    assistant_response: str


# --- Graph Nodes Definition ---
def assistant_draft(state: DraftReviewState) -> DraftReviewState:
    user_message = HumanMessage(content=state["human_request"])
    status = state.get("status", "approved")

    if (status == "feedback" and state.get("human_comment")):
        human_comment = HumanMessage(content=state["human_comment"])

        system_message = SystemMessage(content=(f"""
        You are an AI assistant revising your previous draft. Carefully review the human's 
        feedback and update your reply accordingly. Address all comments, corrections, 
        or suggestions provided by the human. Ensure your revised response fully 
        integrates the feedback, improves clarity, and resolves any issues raised.
        """))

        messages = [user_message] + state["messages"] + [system_message, human_comment]
        all_messages = state["messages"] + [human_comment]

    else:
        system_message = SystemMessage(content=("""
        You are an AI assistant. Your goal is to fully understand and fulfill the user's 
        request by preparing a relevant, clear, and helpful draft reply. Focus on addressing 
        the user's needs directly and comprehensively. 
        Do not reference any previous human feedback at this stage.
        """))
        messages = [system_message, user_message]
        all_messages = state["messages"]
    
    response = model.invoke(messages)

    all_messages = all_messages + [response]

    return {
        **state,
        "messages": all_messages,
        "assistant_response": response.content
    }


def human_feedback(state: DraftReviewState):
    pass


def assistant_finalize(state: DraftReviewState) -> DraftReviewState:
    system_message = """
    You are an AI assistant. The user has approved your draft. Carefully 
    review your reply and make any final improvements to clarity, tone, and 
    completeness. Ensure the response is polished, professional, and ready 
    to be delivered as the final answer.
    """
    messages = [system_message] + state["messages"]
    response = model.invoke(messages)

    all_messages = state['messages'] + [response]

    return {
        **state,
        "messages": all_messages,
        "assistant_response": response.content
    }
    

# --- Router Function ---
def feedback_router(state: DraftReviewState) -> str:
    if state['status'] == 'approved':
        return 'assistant_finalize'
    else:
        return 'assistant_draft'

# --- Graph Construction ---
builder = StateGraph(DraftReviewState)

# builder.add_node('start', start_node)
builder.add_node('assistant_draft', assistant_draft)
builder.add_node('human_feedback', human_feedback)
builder.add_node('assistant_finalize', assistant_finalize)

builder.add_edge(START, 'assistant_draft')
builder.add_edge('assistant_draft', 'human_feedback')
builder.add_conditional_edges('human_feedback', feedback_router, {'assistant_finalize': 'assistant_finalize', 'assistant_draft': 'assistant_draft'})
builder.add_edge('assistant_finalize', END)

memory = MemorySaver()
graph = builder.compile(interrupt_before=["human_feedback"], checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "1"}}

result = graph.invoke({"human_request": "Explain what is HITL, explain this in technical terms"}, config)
result
# Out:
# {'messages': [AIMessage(content='HITL, or Human-in-the-Loop, is a model used in machine learning and artificial intelligence that emphasizes the integration of human feedback and decision-making within automated systems. It is a crucial approach particularly in areas where full automation might not be feasible, desirable, or ethical. Below are the technical aspects of HITL:\n\n1. **Operational Framework**: HITL systems are generally designed to work alongside humans, utilizing human intervention to enhance overall performance. The system can autonomously process data, make predictions, or take actions up to a certain point but relies on human input for final decision-making or during ambiguous scenarios.\n\n2. **Data Annotation and Model Training**: Machine learning models require extensive datasets for training. HITL is often employed during the data annotation phase where human annotators label data to create training datasets. This human involvement ensures that the model learns from high-quality, contextually relevant examples. Furthermore, as models are deployed, HITL can facilitate continuous learning by allowing human operators to correct or provide feedback on model outputs, enabling the model to improve over time.\n\n3. **Iterative Feedback Loops**: HITL systems typically operate on iterative feedback loops. Once the model generates output (e.g., predictions), humans assess the performance and provide feedback, which can be used to retrain the model, enhance its accuracy, and refine its algorithms.\n\n4. **Error Correction and Quality Assurance**: In domains requiring high levels of accuracy (such as healthcare, autonomous driving, or cybersecurity), HITL plays a vital role in error detection and correction. Humans can review outputs from the AI system, identify errors, and make necessary corrections to ensure high reliability and safety in decision-making.\n\n5. **Usability and Interface Design**: Effective HITL systems need well-designed user interfaces that enable human operators to interact seamlessly with AI outputs. This includes visualization tools and dashboards that help users to quickly identify anomalies, interact with model predictions, and provide input where necessary.\n\n6. **Ethical Considerations**: The HITL approach can mitigate biases often found in solely automated systems by introducing diverse human perspectives into the decision-making process. This can enhance the ethical deployment of AI technologies, especially in applications involving critical social issues.\n\n7. **Applications**: Common applications of HITL include natural language processing (NLP), image and video analysis, content moderation, and recommendations systems where nuanced understanding and context from human users enhance the performance and relevance of the system.\n\nIn summary, HITL represents a collaborative framework between humans and AI, where human intelligence is complemented by machine efficiency, allowing for better outcomes in complex decision-making environments.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 525, 'prompt_tokens': 82, 'total_tokens': 607, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ca3e7d71bf', 'id': 'chatcmpl-DL8cjP4FSj7oAu8L3fGGL1Wip5jlS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d067d-eb23-7e81-ba10-b30a9bc38f6f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 82, 'output_tokens': 525, 'total_tokens': 607, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'human_request': 'Explain what is HITL, explain this in technical terms',
#  'assistant_response': 'HITL, or Human-in-the-Loop, is a model used in machine learning and artificial intelligence that emphasizes the integration of human feedback and decision-making within automated systems. It is a crucial approach particularly in areas where full automation might not be feasible, desirable, or ethical. Below are the technical aspects of HITL:\n\n1. **Operational Framework**: HITL systems are generally designed to work alongside humans, utilizing human intervention to enhance overall performance. The system can autonomously process data, make predictions, or take actions up to a certain point but relies on human input for final decision-making or during ambiguous scenarios.\n\n2. **Data Annotation and Model Training**: Machine learning models require extensive datasets for training. HITL is often employed during the data annotation phase where human annotators label data to create training datasets. This human involvement ensures that the model learns from high-quality, contextually relevant examples. Furthermore, as models are deployed, HITL can facilitate continuous learning by allowing human operators to correct or provide feedback on model outputs, enabling the model to improve over time.\n\n3. **Iterative Feedback Loops**: HITL systems typically operate on iterative feedback loops. Once the model generates output (e.g., predictions), humans assess the performance and provide feedback, which can be used to retrain the model, enhance its accuracy, and refine its algorithms.\n\n4. **Error Correction and Quality Assurance**: In domains requiring high levels of accuracy (such as healthcare, autonomous driving, or cybersecurity), HITL plays a vital role in error detection and correction. Humans can review outputs from the AI system, identify errors, and make necessary corrections to ensure high reliability and safety in decision-making.\n\n5. **Usability and Interface Design**: Effective HITL systems need well-designed user interfaces that enable human operators to interact seamlessly with AI outputs. This includes visualization tools and dashboards that help users to quickly identify anomalies, interact with model predictions, and provide input where necessary.\n\n6. **Ethical Considerations**: The HITL approach can mitigate biases often found in solely automated systems by introducing diverse human perspectives into the decision-making process. This can enhance the ethical deployment of AI technologies, especially in applications involving critical social issues.\n\n7. **Applications**: Common applications of HITL include natural language processing (NLP), image and video analysis, content moderation, and recommendations systems where nuanced understanding and context from human users enhance the performance and relevance of the system.\n\nIn summary, HITL represents a collaborative framework between humans and AI, where human intelligence is complemented by machine efficiency, allowing for better outcomes in complex decision-making environments.'}

# %%
graph.update_state(config, values={"status": "feedback","human_comment": "Explain me in 10 words only to a 5 years old"})
result1=graph.invoke(None, config)

# %%
result1
# Out:
# {'messages': [AIMessage(content='HITL, or Human-in-the-Loop, is a model used in machine learning and artificial intelligence that emphasizes the integration of human feedback and decision-making within automated systems. It is a crucial approach particularly in areas where full automation might not be feasible, desirable, or ethical. Below are the technical aspects of HITL:\n\n1. **Operational Framework**: HITL systems are generally designed to work alongside humans, utilizing human intervention to enhance overall performance. The system can autonomously process data, make predictions, or take actions up to a certain point but relies on human input for final decision-making or during ambiguous scenarios.\n\n2. **Data Annotation and Model Training**: Machine learning models require extensive datasets for training. HITL is often employed during the data annotation phase where human annotators label data to create training datasets. This human involvement ensures that the model learns from high-quality, contextually relevant examples. Furthermore, as models are deployed, HITL can facilitate continuous learning by allowing human operators to correct or provide feedback on model outputs, enabling the model to improve over time.\n\n3. **Iterative Feedback Loops**: HITL systems typically operate on iterative feedback loops. Once the model generates output (e.g., predictions), humans assess the performance and provide feedback, which can be used to retrain the model, enhance its accuracy, and refine its algorithms.\n\n4. **Error Correction and Quality Assurance**: In domains requiring high levels of accuracy (such as healthcare, autonomous driving, or cybersecurity), HITL plays a vital role in error detection and correction. Humans can review outputs from the AI system, identify errors, and make necessary corrections to ensure high reliability and safety in decision-making.\n\n5. **Usability and Interface Design**: Effective HITL systems need well-designed user interfaces that enable human operators to interact seamlessly with AI outputs. This includes visualization tools and dashboards that help users to quickly identify anomalies, interact with model predictions, and provide input where necessary.\n\n6. **Ethical Considerations**: The HITL approach can mitigate biases often found in solely automated systems by introducing diverse human perspectives into the decision-making process. This can enhance the ethical deployment of AI technologies, especially in applications involving critical social issues.\n\n7. **Applications**: Common applications of HITL include natural language processing (NLP), image and video analysis, content moderation, and recommendations systems where nuanced understanding and context from human users enhance the performance and relevance of the system.\n\nIn summary, HITL represents a collaborative framework between humans and AI, where human intelligence is complemented by machine efficiency, allowing for better outcomes in complex decision-making environments.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 525, 'prompt_tokens': 82, 'total_tokens': 607, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ca3e7d71bf', 'id': 'chatcmpl-DL8cjP4FSj7oAu8L3fGGL1Wip5jlS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d067d-eb23-7e81-ba10-b30a9bc38f6f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 82, 'output_tokens': 525, 'total_tokens': 607, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='Explain me in 10 words only to a 5 years old', additional_kwargs={}, response_metadata={}, id='5d09af39-6592-4961-ab92-a21f23dcff44'),
#   AIMessage(content='Humans help computers make smart choices and fix mistakes.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 631, 'total_tokens': 642, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b849d285b0', 'id': 'chatcmpl-DL8cw5SOvXFScWJsmhgHrghV5Sz6m', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d067e-1f6f-77b1-b23c-d864ee1d4238-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 631, 'output_tokens': 11, 'total_tokens': 642, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'human_request': 'Explain what is HITL, explain this in technical terms',
#  'human_comment': 'Explain me in 10 words only to a 5 years old',
#  'status': 'feedback',
#  'assistant_response': 'Humans help computers make smart choices and fix mistakes.'}

# %%
Image(graph.get_graph().draw_mermaid_png())
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
