# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate,PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import streamlit as st 
import os 
import sys
sys.path.insert(1, r'D:\Notebooks\LLM\env')
from enviorment import load_env
import os 
from langchain_google_genai import ChatGoogleGenerativeAI
load_env()
from langchain_community.tools.tavily_search import TavilySearchResults
from typing import TypedDict,Annotated,Literal
from pydantic import BaseModel, Field
import operator
from langgraph.graph import StateGraph,START, END,MessagesState

from langgraph.types import Command
from langgraph.checkpoint.memory import InMemorySaver
# model=ChatGoogleGenerativeAI(
#     model="gemini-2.5-flash-lite",   # or gemini-2.0-pro, 1.5-pro, etc.
#     temperature=0.2)
#from langchain_core.messages.utils import trim_messages,count_tokens_approximately
#model=ChatOpenAI()
model=ChatOpenAI(model="gpt-4.1-mini")

# %%
model
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x0000021E0AC8B4D0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000021E0A3C6FD0>, root_client=<openai.OpenAI object at 0x0000021E0AC8AE90>, root_async_client=<openai.AsyncOpenAI object at 0x0000021E0A3C6E90>, model_name='gpt-4.1-mini', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
from pydantic import BaseModel, Field
from typing import List,Annotated,Optional

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)


class ImageSpec(BaseModel):
    placeholder: str = Field(..., description="e.g. [[IMAGE_1]]")
    filename: str = Field(..., description=" e.g. qkv_flow.png")
    alt: str
    caption: str
    prompt: str = Field(..., description="Prompt to send to the image model.")
    size: Literal["1024x1024", "1024x1536", "1536x1024"] = "1024x1024"
    quality: Literal["low", "medium", "high"] = "medium"


class GlobalImagePlan(BaseModel):
    md_with_placeholders: str
    images: List[ImageSpec] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)

    # reducer/image
    merged_md: str
    md_with_placeholders: str
    image_specs: List[dict]

    final: str

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = model.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily) 
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = model.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = model.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = model.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
from pathlib import Path

# %%
# ============================================================
# 8) ReducerWithImages (subgraph)
#    merge_content -> decide_images -> generate_and_place_images
# ============================================================
def merge_content(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    merged_md = f"# {plan.blog_title}\n\n{body}\n"
    return {"merged_md": merged_md}


DECIDE_IMAGES_SYSTEM = """You are an expert technical editor.
Decide if images/diagrams are needed for THIS blog.

Rules:
- Max 1 images total.
- Each image must materially improve understanding (diagram/flow/table-like visual).
- Insert placeholders exactly: [[IMAGE_1]].
- If no images needed: md_with_placeholders must equal input and images=[].
- Avoid decorative images; prefer technical diagrams with short labels.
Return strictly GlobalImagePlan.
"""

def decide_images(state: State) -> dict:
    
    planner = model.with_structured_output(GlobalImagePlan)
    merged_md = state["merged_md"]
    plan = state["plan"]
    assert plan is not None

    image_plan = planner.invoke(
        [
            SystemMessage(content=DECIDE_IMAGES_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Topic: {state['topic']}\n\n"
                    "Insert placeholders + propose image prompts.\n\n"
                    f"{merged_md}"
                )
            ),
        ]
    )

    return {
        "md_with_placeholders": image_plan.md_with_placeholders,
        "image_specs": [img.model_dump() for img in image_plan.images],
    }


def _gemini_generate_image_bytes(prompt: str) -> bytes:
    """
    Returns raw image bytes generated by Gemini.
    Requires: pip install google-genai
    Env var: GEMINI_API_KEY
    """
    from google import genai
    from google.genai import types

    api_key = os.environ.get("GEMINI_API_KEY")
    #if not api_key:
    #    raise RuntimeError("GOOGLE_API_KEY is not set.")

    client = genai.Client(api_key=api_key)

    resp = client.models.generate_content(
        model="gemini-2.5-flash-image",
        contents=prompt,
        config=types.GenerateContentConfig(
            response_modalities=["IMAGE"],
            safety_settings=[
                types.SafetySetting(
                    category="HARM_CATEGORY_DANGEROUS_CONTENT",
                    threshold="BLOCK_ONLY_HIGH",
                )
            ],
        ),
    )

    # Depending on SDK version, parts may hang off resp.candidates[0].content.parts
    parts = getattr(resp, "parts", None)
    if not parts and getattr(resp, "candidates", None):
        try:
            parts = resp.candidates[0].content.parts
        except Exception:
            parts = None

    if not parts:
        raise RuntimeError("No image content returned (safety/quota/SDK change).")

    for part in parts:
        inline = getattr(part, "inline_data", None)
        if inline and getattr(inline, "data", None):
            return inline.data

    raise RuntimeError("No inline image bytes found in response.")


def generate_and_place_images(state: State) -> dict:

    plan = state["plan"]
    assert plan is not None

    md = state.get("md_with_placeholders") or state["merged_md"]
    image_specs = state.get("image_specs", []) or []

    # If no images requested, just write merged markdown
    if not image_specs:
        filename = f"{plan.blog_title}.md"
        Path(filename).write_text(md, encoding="utf-8")
        return {"final": md}

    images_dir = Path("images")
    images_dir.mkdir(exist_ok=True)

    for spec in image_specs:
        placeholder = spec["placeholder"]
        filename = spec["filename"]
        out_path = images_dir / filename

        # generate only if needed
        if not out_path.exists():
            try:
                img_bytes = _gemini_generate_image_bytes(spec["prompt"])
                out_path.write_bytes(img_bytes)
            except Exception as e:
                # graceful fallback: keep doc usable
                prompt_block = (
                    f"> **[IMAGE GENERATION FAILED]** {spec.get('caption','')}\n>\n"
                    f"> **Alt:** {spec.get('alt','')}\n>\n"
                    f"> **Prompt:** {spec.get('prompt','')}\n>\n"
                    f"> **Error:** {e}\n"
                )
                md = md.replace(placeholder, prompt_block)
                print ('exception in image generation ',e)
                continue

        img_md = f"![{spec['alt']}](images/{filename})\n*{spec['caption']}*"
        md = md.replace(placeholder, img_md)
    print ('after md generation ',md)
    filename = f"{plan.blog_title}.md"
    filename=filename.replace(',',' ')
    Path(filename).write_text(md, encoding="utf-8")
    print ('filename is ',filename)
    return {"final": md}

# %%
# build reducer subgraph
reducer_graph = StateGraph(State)
reducer_graph.add_node("merge_content", merge_content)
reducer_graph.add_node("decide_images", decide_images)
reducer_graph.add_node("generate_and_place_images", generate_and_place_images)
reducer_graph.add_edge(START, "merge_content")
reducer_graph.add_edge("merge_content", "decide_images")
reducer_graph.add_edge("decide_images", "generate_and_place_images")
reducer_graph.add_edge("generate_and_place_images", END)
reducer_subgraph = reducer_graph.compile()

reducer_subgraph

# %%
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_subgraph)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

workflow = g.compile()
workflow

# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langgraph.types import Send

# %%
out = workflow.invoke({"topic": "Indian politics", "sections": [],"image_specs": []})
# Out:
# exception in image generation  429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.5-flash-preview-image\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.5-flash-preview-image\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.5-flash-preview-image\nPlease retry in 53.751466561s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-preview-image'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-preview-image'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-preview-image'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '53s'}]}}
# after md generation  # Key Developments Shaping Indian Politics in 2024
#
# ## Overview of the 2024 Indian General Elections
#
# The 2024 Lok Sabha elections were among the largest democratic exercises globally, marked by record voter engagement and intense political competition. Voting took place in multiple phases from April through early June, culminating in a historic turnout of approximately 67.4%, the highest in two decades. This surge in voter participation underscored the electorate's keen interest and reflected heightened political mobilization across urban and rural constituencies alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).
#
# The Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) emerged as the single largest coalition but fell short of securing an outright majority in the 543-seat Lok Sabha, winning around 235 seats significantly less than the 272 needed to form the government independently. This marked a departure from previous elections where the NDA had achieved a comfortable majority. The BJP9;s reduced seat count indicated voter recalibration and vibrant competition from opposition fronts ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).
#
# Regionally, election outcomes revealed varied political dynamics. The BJP saw declines in several key states, losing ground in southern and eastern regions where regional parties and opposition alliances made substantial gains. The Indian National Congress, though still recovering from earlier setbacks, improved its tally modestly, bucking a trend of steady decline. The Aam Aadmi Party (AAP) expanded its footprint beyond Delhi, notably gaining seats in Punjab and parts of the northeast, signaling a shift toward issue-based regional politics. Additionally, regional parties such as the Trinamool Congress in West Bengal and the Dravida Munnetra Kazhagam (DMK) in Tamil Nadu consolidated their power bases, reflecting the electorate9s growing preference for localized governance ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises), [Source](https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray)).
#
# Voter concerns that shaped the election results mainly revolved around unemployment, inflation, and infrastructural development. Rising joblessness among youth and persistent inflation stressed economic challenges, while infrastructure deficits in health, education, and rural development influenced voting patterns. Environmental issues and governance transparency also emerged as secondary yet notable factors. These priorities illustrated a nuanced electorate increasingly demanding tangible improvements alongside ideological allegiance ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).
#
# The election results immediately altered the political landscape. The absence of a clear mandate for the NDA necessitates coalition-building and pragmatic alliances, potentially fostering a more consensus-driven legislative approach. Opposition gains bolstered their voice, setting the stage for stronger parliamentary scrutiny. The diversification of party representation is likely to drive multipolar policy debate, affecting legislation on economic reform, social welfare, and foreign relations. For developers and analysts, these shifts suggest an evolving regulatory environment with potential impacts on technology investments, digital infrastructure policies, and innovation incentives ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).
#
# > **[IMAGE GENERATION FAILED]** 2024 Indian General Election Results by State and Major Parties
# >
# > **Alt:** Map of India showing 2024 Lok Sabha election results by party and region
# >
# > **Prompt:** A detailed color-coded map of India showing the 2024 Lok Sabha election results by state and major political parties, highlighting BJP-led NDA seats, opposition alliances, and regional party strongholds, with clear labels and legend.
# >
# > **Error:** 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.5-flash-preview-image\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.5-flash-preview-image\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.5-flash-preview-image\nPlease retry in 53.751466561s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-preview-image'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-preview-image'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-preview-image'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '53s'}]}}
#
#
# In conclusion, the 2024 Indian general elections represent a critical juncture, marked by increased voter participation, a more fragmented parliamentary outcome, and clear signals of changing public expectations. The emerging pluralistic political scenario promises a period of dynamic policy formulation and governance adjustment with broad implications across sectors.
#
# ## Regional Political Dynamics and Key State Elections
#
# State-level elections in Bihar, Delhi, and Jammu & Kashmir in 2024 played a pivotal role in shaping India9s broader political landscape, influencing the balance of power and the trajectory of national policy-making.
#
# ### NDA9s Decisive Win in Bihar: Cementing BJP9s National Strength
#
# The National Democratic Alliance (NDA), led by the Bharatiya Janata Party (BJP), secured a decisive victory in Bihar's state elections. This result reinforced BJP's dominant position in one of India's most politically significant states, characterized by a large voter base and strategic location. The win consolidates the NDA9s grassroots organizational strength and sends a strong signal about BJP9s enduring appeal in regional politics, boosting its mandate ahead of subsequent national elections. This victory also strengthens BJP's capacity to mobilize rural and caste-based vote banks a crucial factor in Indian electoral politics ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises)).
#
# ### BJP9s Return to Power in Delhi after Decades: Factors Behind the Shift
#
# In Delhi, the BJP made a remarkable comeback after nearly 30 years, ending a long period of dominance by the Aam Aadmi Party (AAP). Key factors propelling this shift included effective campaigning focused on national security, economic development promises, and voter outreach to middle-class urban populations. Additionally, the BJP leveraged growing dissatisfaction with local governance on issues like public services and infrastructure. This shift highlights BJP9s strategic recalibration to urban electorates and suggests potential implications for governance models that blend local and central priorities ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).
#
# ### Historic Elections in Jammu & Kashmir: Voter Participation and Political Context
#
# The 2024 Jammu & Kashmir elections marked a historic milestone, being the first comprehensive democratic exercise in the region since the revocation of its special status in 2019. Voter turnout was notably high despite security concerns and regional unrest, reflecting a strong desire among residents for political representation and inclusion in the Indian democratic process. These elections introduced new political dynamics, with traditional parties and newcomers competing in a reshaped governance framework under direct central administration. The results have significant implications for peacebuilding, regional autonomy debates, and the integration of Jammu & Kashmir into national political discourse ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).
#
# ### Impact of State Elections on Coalition-Building and National Policy Directions
#
# State elections remain critical to coalition-building at the national level, especially in India9s multiparty landscape. Victories in states like Bihar and Jammu & Kashmir enhance BJP9s bargaining power within alliances, affecting the composition and stability of government coalitions. This, in turn, influences policymaking priorities such as federal resource allocation, social welfare schemes, and security policies. State governments aligned with the Centre facilitate smoother policy implementation, whereas opposition-led states may catalyze political contestation and negotiation, shaping the legislative agenda and balancing central-state relations ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)).
#
# ### Electoral Reforms: Voter List Revisions Enhancing Legitimacy
#
# To ensure the integrity of these critical elections, the Election Commission of India undertook extensive voter list revisions, targeting bogus entries and duplications. These reforms aimed to enhance electoral legitimacy by improving accuracy in voter rolls, thereby preventing electoral fraud and fostering greater trust in democratic processes. Updated and cleaned voter lists helped increase effective voter participation, especially among marginalized sections, contributing to fairer and more transparent elections that better reflect popular will ([Source](https://politypolicy.substack.com/p/india-this-year-25-events-that-shaped)).
#
# ---
#
# The outcomes and processes of these key state elections provide actionable insights into India9s evolving political dynamics. For technically minded observers, the intersection of regional political shifts with data-driven electoral reforms offers a nuanced perspective on how local contests reverberate through national power structures and policy trajectories.
#
# ## Economic and Social Issues Influencing the 2024 Elections
#
# Economic conditions were a pivotal factor shaping voter behavior and campaign strategies in India9s 2024 general elections. Unemployment and inflation emerged as primary concerns for a broad spectrum of voters, significantly affecting party support. According to several analyses, rising inflation, especially in food and fuel prices, eroded disposable incomes and deepened economic anxieties among urban and rural populations alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)). High unemployment rates, particularly among youth, added to voter dissatisfaction, partially explaining the erosion of support for incumbent parties in key constituencies.
#
# While Hindu nationalism continued to shape the political discourse, its mass appeal encountered limits amid pressing economic grievances. Voters increasingly prioritized livelihood, job security, and price stability over identity-based narratives. Reports suggest that parties leveraging Hindu nationalist themes faced challenges expanding their vote base in economically distressed regions where immediate material concerns took precedence ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)). This dynamic forced parties, especially the ruling coalition, to recalibrate their messaging to foreground economic promises.
#
# Interestingly, despite India maintaining steady GDP growth figureshovering around 6-7% annuallythe disconnect between macroeconomic growth and public satisfaction was stark. Many voters perceived growth as uneven, with benefits concentrated in specific sectors and urban centers, failing to translate into widespread economic upliftment. This disparity shaped political messaging, as opposition groups highlighted the contrast between official data and ground realities, framing themselves as champions of equitable development ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).
#
# Major parties adopted nuanced campaign strategies to address these intertwined economic and social issues. The ruling party emphasized infrastructural development and job creation schemes, attempting to assuage economic anxieties while maintaining its cultural-nationalist base. Simultaneously, opposition coalitions centered their campaigns on anti-inflation rhetoric, rural distress, and inclusive welfare policies, seeking to capitalize on the electorate9s economic frustrations. Digital outreach and grassroots mobilization were key tools deployed to articulate these contrasting narratives effectively across diverse demographics ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises)).
#
# Regionally, economic concerns showed marked disparities reflected in the election outcomes. States with higher unemployment and inflation levels experienced stronger swings against the ruling party, evidencing a direct correlation between local economic stress and electoral volatility. For example, eastern and central states with agrarian distress and industrial slowdowns witnessed gains for opposition parties, whereas southern and western states, benefitting from relatively robust industrial growth and urban employment, displayed more stable incumbent support ([Source](https://politypolicy.substack.com/p/india-this-year-25-events-that-shaped)). This regional variation underscored the complexity of economic issues influencing voter choices beyond national-level narratives.
#
# In summary, economic hardships around unemployment and inflation played a decisive role in shaping voter behavior by limiting the scope of identity-focused appeals, engendering skepticism about macroeconomic growth figures, and compelling parties to adopt more economically grounded campaign strategies. The resulting electoral landscape highlighted the critical importance of addressing tangible economic concerns alongside social narratives to secure broad-based political support in India9s evolving democracy.
#
# ## International Relations and Diplomatic Tensions Affecting Indian Politics
#
# In 2024, India9s international relations witnessed heightened diplomatic tensions, particularly with Canada and the United States, revolving around allegations linked to assassinations of Sikh separatist leaders. These accusations triggered a notable diplomatic fallout, straining ties with both countries. India accused some elements within the Sikh diaspora in Canada and the US of harboring separatist sympathies and facilitating anti-India activities, leading to formal protests and demand for tighter surveillance on these communities. This diplomatic row unfolded amid growing concerns over national security and sovereignty, gaining substantial attention in India9s domestic political discourse ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).
#
# Political parties leveraged these tensions strategically during the 2024 electoral campaigns. The ruling party framed the issue as a question of India9s international stature and territorial integrity, appealing to nationalist sentiments. Opposition groups criticized the government for diplomatic mismanagement and called for balanced foreign policies that safeguard Indian interests without isolating global partners. This narrative became a polarizing theme in public debates and rallies, often influencing voter perceptions on governance and diplomatic efficacy ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).
#
# Trade agreements and international cooperation prospects were also impacted. Uncertainty surrounding diplomatic relations raised concerns about potential delays or renegotiations of ongoing trade talks with the US and Canada, two significant economic partners for India. Business sectors expressed apprehension about supply chain disruptions, tariff impositions, and visa regulations that could arise amid diplomatic friction. Consequently, policymakers have reported attempts to intensify backchannel communications to mitigate risks and safeguard critical economic ties while addressing security concerns ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)).
#
# Public and media response within India was markedly attentive and often showed nationalistic leanings. News outlets prominently covered developments related to the diplomatic tensions, with editorials frequently urging a firm stance by the government. Social media trends reflected a mixture of support for sovereignty-focused policies and calls for diplomatic prudence. Several Indian diaspora groups staged demonstrations to both support and critique government responses, indicating the contentious nature of the issue among expatriate communities as well ([Source](https://www.thehindu.com/news/national/)).
#
# Overall, these international relations challenges had a pronounced impact on India9s political positioning in 2024. The government9s handling of foreign policy issues became a litmus test for its competency on the global stage, shaping narratives about India9s emerging role as a regional power. Additionally, the diplomatic tensions influenced coalition dynamics within Parliament and electoral outcomes by energizing voter bases around sovereignty and diplomatic assertiveness. These events underscored how interconnected security concerns, international diplomacy, and domestic political agendas are in contemporary Indian politics ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).
#
# ## Key Incidents and Political Events Beyond Elections
#
# The political landscape in India in 2024 was shaped not only by the general elections but also by several major developments inside and outside Parliament, impacting governance and political discourse significantly.
#
# ### Parliamentary Dynamics and Modi9s Rajya Sabha Address
#
# Post-elections, the Lok Sabha sessions experienced visible disruptions with opposition parties raising strong objections over policy priorities and governance issues. These interruptions reflected intense political rivalry and challenges in passing key legislations. Prime Minister Narendra Modi9s address to the Rajya Sabha was a crucial moment, where he outlined the government9s vision for the next five years, emphasizing economic growth, national security, and diplomatic priorities. His speech aimed to pacify critics and assert a narrative of stability despite fragmented mandates in the Lok Sabha ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).
#
# ### Resolution of the India-China Border Situation
#
# A significant diplomatic breakthrough occurred with India and China resolving key issues related to their contentious border areas. The de-escalation of military standoffs improved bilateral ties and reduced security anxieties. Politically, this resolution consolidated the incumbent government9s credibility in managing foreign affairs and national security, bolstering domestic support amidst global uncertainty. Analysts noted that stable India-China relations allowed policymakers to refocus on internal development agendas without the looming threat of border conflicts ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).
#
# ### Social and Political Protests Influencing Political Opinion
#
# The year also saw widespread social and political protests concerning agrarian reforms, labor laws, and urban governance. These movements highlighted discontent in various segments of society and exerted pressure on both central and state governments to revisit contentious policies. The protests became a barometer of shifting political opinions, especially among youth and marginalized communities, signaling potential realignments ahead in party support bases. They underscored challenges in balancing economic reforms with social equity ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)).
#
# ### India9s T20 World Championship Victory as a National Unifier
#
# In a contrasting but significant development, India9s triumph in the T20 World Cup emerged as a unifying event that momentarily transcended political divisions. The victory fostered a collective sense of national pride across diverse demographics. This sport achievement provided positive momentum for the government in managing public sentiment amid ongoing political debates and challenges. It demonstrated the power of national events in shaping political narratives beyond policy and elections ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).
#
# ### Contributions to Political Narratives and Governance Challenges
#
# Together, these events influenced the political discourse and governance framework in 2024:
#
# - Parliamentary obstructions and Modi9s assertive Rajya Sabha address highlighted uncertainties in legislative functioning and the need for coalition-building.
# - Resolution with China reinforced national security narratives and enabled policy focus shifts.
# - Social unrest revealed fractures in public consensus, alerting policymakers to socio-economic grievances.
# - Sports success offered a critical soft power lever to unite the populace amid political fragmentation.
#
# In sum, these key incidents exemplified the complex interplay of diplomacy, domestic policy, social movements, and symbolic victories shaping India9s governance and political narratives through 2024 ([Source](https://politypolicy.substack.com/p/india-this-year-25-events-that-shaped)).
#
# ## Emerging Political Alliances and Opposition Realignments
#
# The 2024 Indian general elections have catalyzed significant shifts in political alliances and opposition strategies, reshaping the landscape of competition and governance prospects in India.
#
# ### The Indian National Developmental Inclusive Alliance (INDIA Alliance)
#
# Formed as a broad coalition of opposition parties, the Indian National Developmental Inclusive Alliance (INDIA alliance) emerged to consolidate dissent against the ruling Bharatiya Janata Party (BJP). Member parties include the Indian National Congress, Trinamool Congress, Nationalist Congress Party, and several regional players aiming to pool resources and voter bases to improve electoral performance.
#
# Despite varied success across states, the alliance succeeded in winning notable seats, impacting the electoral arithmetic substantially. It demonstrated the potential strength of strategic coalition-building but also revealed cracks due to ideological heterogeneity and regional leadership ambitions ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).
#
# ### BJP9s Internal Reorganization
#
# Parallelly, the BJP undertook strategic internal reorganization under the leadership of Prime Minister Narendra Modi and party strategist Amit Shah. This reorganization reinforced centralized control mechanisms, streamlined candidate selections, and tightened party discipline, which enhanced organizational coherence and electoral machinery efficiency ([Source](https://www.thehindu.com/news/national/)).
#
# The consolidation within BJP helped it navigate challenges posed by increasingly coordinated opposition efforts and maintain a dominant position in several key states.
#
# ### Opposition Fragmentation and Realignment Challenges
#
# However, the opposition alliance faces inherent challenges related to fragmentation and realignment. Deep-rooted regional loyalties, policy disagreements, and competition for leadership roles continue to hamper a fully unified front. Post-election, several regional parties reassessed their alignments, leading to shifting blocs and tactical realignments that could complicate collaborative governance plans ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).
#
# These challenges underscore the complexity of alliance politics in India's multifaceted political environment and suggest that cohesion remains a key obstacle for opposition effectiveness.
#
# ### Election Allegations and Political Stability
#
# The 2024 elections were also marked by allegations ranging from vote theft claims to manipulation of electronic voting machines, creating tensions that permeated both pre- and post-election phases. Such disputes have unsettled political stability, provoking public distrust in the electoral process. While investigative bodies and courts have intervened, the controversies have strained inter-party relations and complicated policy consensus-building ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).
#
# Effective resolution mechanisms and transparency enhancements remain critical to restoring electoral integrity and political stability moving forward.
#
# ### Reshaping Political Competition and Governance Prospects
#
# The evolving alliances have fundamentally reshaped the dynamics of political competition. The INDIA alliance signals a shift toward multi-polar contestation, moving away from BJP9s erstwhile electoral dominance. This has introduced greater uncertainty, requiring new governance coalitions that must balance ideological diversity and regional interests.
#
# The future governance landscape will likely feature more negotiated settlements and coalition accommodations, challenging the traditional single-party majority model that defined previous BJP administrations. For developers and technical professionals analyzing political trends, these developments highlight the increasing complexity in Indian polity, necessitating nuanced understanding of alliance politics and its impacts on policy continuity and reform trajectories ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).
#
# ---
#
# In summary, the 2024 elections have catalyzed a reconfiguration of India9s political alliances, with the INDIA alliance representing an unprecedented opposition effort, BJP consolidating control internally, and ongoing opposition fragmentation presenting both obstacles and opportunities. Election-related disputes introduce risks to political stability, and the new multi-polar competition model is set to influence governance and policy directions significantly in the coming years.
# filename is  Key Developments Shaping Indian Politics in 2024.md

# %%
out['final']
# Out:
# "# 2024 and Beyond: Key Developments in Indian Politics\n\n## Overview of the 2024 Indian General Elections and Political Landscape\n\nThe 2024 Indian general elections resulted in a politically significant outcome marked by notable shifts in party strengths and regional dynamics. The Bharatiya Janata Party (BJP) secured its third consecutive term; however, it faced a reduced seat count compared to previous elections. This outcome compelled the BJP to rely more heavily on coalition partners to maintain a parliamentary majority, signaling a slight erosion in its electoral dominance ([Al Jazeera](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises)).\n\nIn contrast, the opposition INDIA alliance made substantial gains, particularly the Indian National Congress, which effectively doubled its parliamentary seats. This upswing for Congress represents a revival of influence after years of marginalization and points to increased voter traction for the alliance's platforms and leadership ([Boell Foundation](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nSeveral surprising election results underscored the evolving political landscape. The BJP lost ground in West Bengal, a state long dominated by regional parties and now leaning towards the opposition alliance. Conversely, the BJP secured its first-ever parliamentary win in Kerala, traditionally a stronghold of leftist and regional parties, marking a notable breach in regional political barriers. These victories and losses highlight both the adaptability and vulnerability of national parties in India's diverse electoral environment ([Al Jazeera](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises)).\n\nThe persistence and influence of state-based parties remain a defining element of India's national politics. Regional parties continued to command significant voter bases in states like Tamil Nadu, Telangana, and Odisha, often acting as kingmakers in coalition formations. This underscores a federal dynamic where regional identities and issues retain strong electoral relevance, shaping policy priorities and government composition at the national level ([Boell Foundation](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nThese electoral outcomes collectively indicate an evolving political dynamic in India, characterized by declining single-party majorities, rising coalition politics, and increased competition from regional and opposition alliances. The electorate appears more fragmented, with voter preferences reflecting complex social, economic, and identity-based cleavages.\n\nFrom a demographic perspective, voter participation remained robust with turnout statistics close to historic highs, reflecting sustained electoral engagement. The election also saw an increase in younger and more diverse candidate profiles, including more women and candidates from minority communities, signaling gradual shifts toward greater political inclusivity ([PRS India](https://prsindia.org/parliamenttrack/vital-stats/profile-of-candidates-contesting-in-general-elections-2024)).\n\nIn summary, the 2024 general elections reveal a maturing and more contested democratic process in India, with implications for governance, policy formulation, and the balance of power both within national politics and vis-à-vis regional actors. This complex landscape will significantly influence India's political stability and policy directions in the coming years.\n\n> **[IMAGE GENERATION FAILED]** Geographic distribution of key political party victories and losses in the 2024 Indian general elections.\n>\n> **Alt:** Map of India showing 2024 general election results by state and party\n>\n> **Prompt:** Create a detailed map of India highlighting states by dominant political party in the 2024 general elections, showing BJP, Congress, and regional parties with c ...

# %%
out
# Out:
# {'topic': 'Indian politics',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['Current major political events in India 2024',
#   'Latest developments in Indian general elections 2024',
#   'Recent political party realignments in India',
#   'Current opinion polls for Indian political parties 2024',
#   'Updates on major Indian government policies in 2024',
#   'Recent statements by Indian Prime Minister and major leaders 2024',
#   'Key political controversies in India April 2024',
#   'Latest political protests and movements in India 2024'],
#  'evidence': [EvidenceItem(title='10 Key Events That Shaped India in 2024 - Newsreel Asia', url='https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024', published_at=None, snippet="India's diplomatic relations with Canada and the United States deteriorated significantly due to allegations of India’s involvement in the assassination of Sikh separatist leaders on foreign soil.", source=None),
#   EvidenceItem(title='The 2024 Indian election: a new political landscape unfolds', url='https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds', published_at=None, snippet='Indians are most concerned about unemployment, inflation and development. The mass appeal of aggressive Hindu nationalism seems to have its limits, and negative sentiment about economic realities prevailed over growth figures.', source=None),
#   EvidenceItem(title='India This Year: 25 Events That Shaped 2025', url='https://politypolicy.substack.com/p/india-this-year-25-events-that-shaped', published_at=None, snippet="NDA's thumping win in Bihar and BJP returning to govern Delhi after almost three decades; Election Commission's revision exercise to ensure rightful citizens vote.", source=None),
#   EvidenceItem(title='Year Ender 2024: 10 big events India witnessed during the year', url='https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms', published_at=None, snippet="Major events include India's biggest election, state elections, historic Jammu and Kashmir election, India-China border resolution, and India becoming T20 World Champions.", source='The Economic Times'),
#   EvidenceItem(title='Live Politics News from India, Latest Politics headlines', url='https://m.economictimes.com/news/politics', published_at=None, snippet='Opposition MPs disrupted Lok Sabha; PM Modi addressed Rajya Sabha; developments include J&K polls and political conflicts in various regions.', source='The Economic Times'),
#   EvidenceItem(title='India Latest News: Top National Headlines Today ... - The Hindu', url='https://www.thehindu.com/news/national/', published_at=None, snippet="Covers India-U.S. trade pact debates, political protests, PM Modi's visits, and various national news reports.", source='The Hindu'),
#   EvidenceItem(title='Lok Sabha elections 2024: India candidates, key issues ...', url='https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd', published_at=None, snippet='Coverage of the seventh and final phase of Lok Sabha elections in India with voting details and candidate information.', source='AP News'),
#   EvidenceItem(title='India election 2024: Why Modi failed to win outright majority - BBC', url='https://www.bbc.com/news/articles/c977g8gl5q2o', published_at=None, snippet="Modi's BJP won but fell short of majority due to joblessness, rising prices, divisive campaigns, and loss in key states like Uttar Pradesh.", source='BBC'),
#   EvidenceItem(title='Indian Lok Sabha elections of 2024 | Process, Schedule ...', url='https://www.britannica.com/event/Indian-Lok-Sabha-elections-of-2024', published_at=None, snippet="India's 2024 general election had record voter turnout; BJP-led NDA won enough seats to form government but BJP fell short of majority; notable regional results.", source='Britannica'),
#   EvidenceItem(title='India elections 2024 - DW.com', url='https://www.dw.com/en/india-elections-2024/t-68826548', published_at=None, snippet="Prime Minister Modi's BJP won most seats but with less than expected; opposition alleges vote theft; analyses of election outcomes.", source='DW'),
#   EvidenceItem(title='India election results: Big wins, losses and surprises - Al Jazeera', url='https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises', published_at=None, snippet='Uttar Pradesh saw a tight race with rise of Samajwadi Party; BJP lost significant seats including Faizabad; INDIA alliance gained seats.', source='Al Jazeera'),
#   EvidenceItem(title='India election 2024: Which are the main political parties in ...', url='https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray', published_at=None, snippet='Profiles of main political parties including BJP, Congress, AAP, DMK, TMC, and others competing in 2024 elections.', source='Al Jazeera'),
#   EvidenceItem(title='India 2022: Political realignments in a BJP-dominated system', url='https://www.asiamaior.org/the-journal/17-asia-maior-vol-xxxiii-2022/india-2022-political-realignments-in-a-bjp-dominated-system.html', published_at=None, snippet="BJP reorganization strengthened Modi and Shah's control; opposition in disarray ahead of 2024 elections.", source='Asia Maior'),
#   EvidenceItem(title='List of current Indian governing and opposition parties - Wikipedia', url='https://en.wikipedia.org/wiki/List_of_current_Indian_governing_and_opposition_parties', published_at=None, snippet='Current list of Indian governing and opposition parties with states and latest election years noted.', source='Wikipedia'),
#   EvidenceItem(title='Nationalist Congress Party - Wikipedia', url='https://en.wikipedia.org/wiki/Nationalist_Congress_Party', published_at=None, snippet='Information about Nationalist Congress Party, its history, factions, and recent electoral performance.', source='Wikipedia'),
#   EvidenceItem(title='Indian National Developmental Inclusive Alliance', url='https://en.wikipedia.org/wiki/Indian_National_Developmental_Inclusive_Alliance', published_at=None, snippet='Details about the INDIA alliance parties, seats contested and won, and their election strategies in 2024 elections.', source='Wikipedia'),
#   EvidenceItem(title='Kavitha signals new party launch in three months - The Hans India', url='https://www.thehansindia.com/telangana/kavitha-signals-new-party-launch-in-three-months-1046213', published_at=None, snippet='Kavitha announces plans to launch a new political party in Telangana within three months, expected around April or May 2024.', source='The Hans India'),
#   EvidenceItem(title='Splits and Mergers of Kerala Congress - Wikipedia', url='https://en.wikipedia.org/wiki/Splits_and_Mergers_of_Kerala_Congress', published_at=None, snippet='Historical context and details on splits and mergers of Kerala Congress party and its factions over the years.', source='Wikipedia'),
#   EvidenceItem(title="Axis My India's 2024 Exit Poll – Report Card & Deep Dive", url="http://axismyindia.org/assests/Axis%20My%20India's%202024%20Exit%20Poll%20-%20Report%20Card%20&%20Deep%20Dive.pdf", published_at=None, snippet='Comprehensive exit poll survey of 2024 Lok Sabha elections with predictions and results for various states and parties.', source='Axis My India'),
#   EvidenceItem(title='India: vote share elections by party 2024', url='https://www.statista.com/statistics/1471977/india-vote-share-elections-by-party/?srsltid=AfmBOoqoFRkQmiHhhiNpBYelFHfiVapTCAyHGceibdy2TLeUrqoeDGQ_', published_at=None, snippet='BJP led with 36.5% vote share; Congress 21.19%; other parties listed with vote shares in 2024 general elections in India.', source='Statista'),
#   EvidenceItem(title="India exit polls: Modi's alliance projected to win majority", url='https://www.aljazeera.com/news/liveblog/2024/6/1/india-election-exit-polls-live-news-will-modi-win-a-rare-third-term-as-pm', published_at=None, snippet="Exit polls project Modi's BJP-led alliance to win majority in 2024 general elections.", source='Al Jazeera'),
#   EvidenceItem(title='India election 2024 updates: 49 seats vote in Phase 5 of ...', url='https://www.aljazeera.com/news/liveblog/2024/5/20/india-election-2024-live-news-49-seats-vote-in-phase-5-of-lok-sabha-polls', published_at=None, snippet='Coverage of Phase 5 voting of 2024 Lok Sabha elections, focusing on key leaders and election stakes.', source='Al Jazeera'),
#   EvidenceItem(title='BJP Dominates Election Polls But Loses Southern India', url='https://www.statista.com/chart/32073/share-of-lok-sabha-seats-projected-to-be-won-by-the-bjp-and-allied-parties/?srsltid=AfmBOopo7-4nE8jUL1dPkzZ5aHVXwVbqDOTorkkWmlaBUNhzVoDOa3Ho', published_at=None, snippet='BJP dominance in northern and central India while losing ground in South India to opposition parties such as Congress and DMK in 2024 elections.', source='Statista'),
#   EvidenceItem(title='10 big-bang policy moves Modi government made in 2024', url='https://m.economictimes.com/news/economy/policy/10-big-bang-policy-moves-modi-government-made-in-2024/articleshow/116701123.cms', published_at=None, snippet="Modi government's 2024 key policies include One Nation One Election, BioE3 policy for biotechnology, urban planning reforms, and initiatives to boost economic growth.", source='The Economic Times'),
#   EvidenceItem(title='India: Freedom in the World 2024 Country Report', url='https://freedomhouse.org/country/india/freedom-world/2024', published_at=None, snippet='Reports on political repression, judicial politicization, ethnic discrimination, and restrictions on expression under Modi government in 2024.', source='Freedom House'),
#   EvidenceItem(title='World Report 2024: India | Human Rights Watch', url='https://www.hrw.org/world-report/2024/country-chapters/india', published_at=None, snippet='Documentation of human rights abuses in India in 2024 including police inaction, administrative repression, internet shutdowns, and ethnic violence in Manipur.', source='Human Rights Watch'),
#   EvidenceItem(title='2024 in India', url='https://en.wikipedia.org/wiki/2024_in_India', published_at=None, snippet='Chronology of key events in India during 2024 including political developments, elections, and social issues.', source='Wikipedia'),
#   EvidenceItem(title='List of schemes of the government of India', url='https://en.wikipedia.org/wiki/List_of_schemes_of_the_government_of_India', published_at=None, snippet='Listing of various government schemes launched or ongoing in India, including PM E-DRIVE and Amrit Bharat Station schemes in 2024.', source='Wikipedia'),
#   EvidenceItem(title="Union Budget 2024-25: India's Next Generation Reforms ...", url='https://www.pib.gov.in/PressReleaseIframePage.aspx?PRID=2036499', published_at='2024-07-24', snippet='Union Budget 2024-25 focuses on next generation reforms to enhance economic growth, productivity, and collaboration between Centre and states.', source='Press Information Bureau, India'),
#   EvidenceItem(title='India-UK Relations - Consulate General of India, Manchester', url='https://cgimanchester.gov.in/pages/MTc,', published_at=None, snippet='In 2024, UK PM Keir Starmer and India PM Modi discussed bilateral relations, trade, defense cooperation, and upcoming visits to strengthen ties.', source='Consulate General of India, Manchester'),
#   EvidenceItem(title="United States-India Joint Leaders' Statement", url='https://www.whitehouse.gov/briefings-statements/2025/02/united-states-india-joint-leaders-statement/', published_at=None, snippet='Leaders of US and India reaffirm Comprehensive Global Strategic Partnership and announce plans for enhanced cooperation across security, trade, and regional partnerships.', source='White House'),
#   EvidenceItem(title='India Votes 2024: A resurgent Hindu nationalism sets the ...', url='https://acleddata.com/report/india-votes-2024-resurgent-hindu-nationalism-sets-stage-upcoming-elections-driving-communal', published_at=None, snippet='Rising Hindu nationalism and religious polarization fueled communal violence and tensions in 2024 elections in India.', source='ACLED'),
#   EvidenceItem(title='India Votes 2024: Economic discontent deepens ethnic ...', url='https://acleddata.com/report/india-votes-2024-economic-discontent-deepens-ethnic-divisions-ahead-elections', published_at=None, snippet='Economic hardships exacerbate ethnic divisions and political unrest ahead of 2024 elections, impacting caste-based affirmative action debates.', source='ACLED'),
#   EvidenceItem(title='India sees huge spike in hate speech in 2024, says report', url='https://www.bbc.com/news/articles/cpwx9942x72o', published_at=None, snippet='Instances of hate speech against minorities, especially Muslims, surged 74% in India in 2024 with political rallies and BJP-ruled states as major sites.', source='BBC')],
#  'plan': Plan(blog_title='Key Developments Shaping Indian Politics in 2024', audience='Developers and technical professionals interested in political trends and their implications', tone='Informative and analytical', blog_kind='news_roundup', constraints=['Use fresh, verifiable sources only', 'Focus on actionable analysis and implications', 'Avoid tutorial content'], tasks=[Task(id=1, title='Overview of the 2024 Indian General Elections', goal='Summarize the major outcomes and voter engagement in the 2024 Lok Sabha elections.', bullets=['Describe the scale of the 2024 elections including record voter turnout and key dates.', "Summarize the results, including BJP-led NDA's performance and the shortfall from outright majority.", 'Highlight regional election outcomes and the rise or decline of major parties like BJP, Congress, AAP, and others.', 'Discuss the main voter concerns such as unemployment, inflation, and development issues as influencing election results.', 'Analyze immediate political landscape changes following the election outcomes.'], target_words=500, tags=['elections', '2024', 'voter turnout', 'party performance'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='Regional Political Dynamics and Key State Elections', goal='Explain the significance of state-level elections in Bihar, Delhi, and Jammu & Kashmir and their impact on national politics.', bullets=["Discuss NDA's decisive win in Bihar and its implications for BJP’s national strength.", 'Outline BJP’s return to power in Delhi after nearly three decades and the factors behind this shift.', 'Explain the historic Jammu & Kashmir elections, voter participation, and political context in the region.', 'Discuss how state elections affect coalition-building and policy directions at the national level.', 'Highlight electoral reforms such as Election Commission’s voter list revisions to ensure legitimate voting.'], target_words=480, tags=['state elections', 'Bihar', 'Delhi', 'Jammu & Kashmir', 'coalitions'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Economic and Social Issues Influencing the 2024 Elections', goal='Analyze how economic conditions and social sentiments shaped voter behavior and campaign strategies.', bullets=['Examine unemployment and inflation as primary voter concerns impacting party support.', 'Discuss the limits of Hindu nationalism’s mass appeal amid economic grievances.', 'Analyze economic growth figures versus public satisfaction and how this affected political messaging.', 'Review campaign strategies used by major parties to address or exploit economic and social issues.', 'Highlight any regional disparities in economic concerns reflected in election results.'], target_words=460, tags=['economy', 'social issues', 'campaign strategies', 'voter behavior'], requires_research=True, requires_citations=True, requires_code=False), Task(id=4, title='International Relations and Diplomatic Tensions Affecting Indian Politics', goal="Detail how international incidents influenced India's domestic political discourse in 2024.", bullets=['Summarize the diplomatic fallout with Canada and the US over allegations relating to Sikh separatist leader assassinations.', 'Discuss how these foreign relations tensions were addressed or used by political parties during campaigns.', 'Consider potential implications for trade agreements and international cooperation.', 'Analyze public and media response to these diplomatic issues within India.', 'Assess the impact of international relations on India’s political positioning in 2024.'], target_words=420, tags=['international relations', 'diplomacy', 'India-US', 'India-Canada', 'political impact'], requires_research=True, requires_citations=True, requires_code=False), Task(id=5, title='Key Incidents and Political Events Beyond Elections', goal='Review other major political developments and events in 2024 shaping India’s political landscape. ...
#  'sections': [(1,
#    "## Overview of the 2024 Indian General Elections\n\nThe 2024 Lok Sabha elections were among the largest democratic exercises globally, marked by record voter engagement and intense political competition. Voting took place in multiple phases from April through early June, culminating in a historic turnout of approximately 67.4%, the highest in two decades. This surge in voter participation underscored the electorate's keen interest and reflected heightened political mobilization across urban and rural constituencies alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nThe Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) emerged as the single largest coalition but fell short of securing an outright majority in the 543-seat Lok Sabha, winning around 235 seats—significantly less than the 272 needed to form the government independently. This marked a departure from previous elections where the NDA had achieved a comfortable majority. The BJP’s reduced seat count indicated voter recalibration and vibrant competition from opposition fronts ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).\n\nRegionally, election outcomes revealed varied political dynamics. The BJP saw declines in several key states, losing ground in southern and eastern regions where regional parties and opposition alliances made substantial gains. The Indian National Congress, though still recovering from earlier setbacks, improved its tally modestly, bucking a trend of steady decline. The Aam Aadmi Party (AAP) expanded its footprint beyond Delhi, notably gaining seats in Punjab and parts of the northeast, signaling a shift toward issue-based regional politics. Additionally, regional parties such as the Trinamool Congress in West Bengal and the Dravida Munnetra Kazhagam (DMK) in Tamil Nadu consolidated their power bases, reflecting the electorate's growing preference for localized governance ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises), [Source](https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray)).\n\nVoter concerns that shaped the election results mainly revolved around unemployment, inflation, and infrastructural development. Rising joblessness among youth and persistent inflation stressed economic challenges, while infrastructure deficits in health, education, and rural development influenced voting patterns. Environmental issues and governance transparency also emerged as secondary yet notable factors. These priorities illustrated a nuanced electorate increasingly demanding tangible improvements alongside ideological allegiance ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).\n\nThe election results immediately altered the political landscape. The absence of a clear mandate for the NDA necessitates coalition-building and pragmatic alliances, potentially fostering a more consensus-driven legislative approach. Opposition gains bolstered their voice, setting the stage for stronger parliamentary scrutiny. The diversification of party representation is likely to drive multipolar policy debate, affecting legislation on economic reform, social welfare, and foreign relations. For developers and analysts, these shifts suggest an evolving regulatory environment with potential impacts on technology investments, digital infrastructure policies, and innovation incentives ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nIn conclusion, the 2024 Indian general elections represent a critical juncture, marked by increased voter participation, a more fragmented parliamentary outcome, and clear signals of changing public expectations. The emerging pluralistic political scenario promises a period of dynamic policy formulation and governance adjustment with broad implic ...
#   (2,
#    "## Regional Political Dynamics and Key State Elections\n\nState-level elections in Bihar, Delhi, and Jammu & Kashmir in 2024 played a pivotal role in shaping India's broader political landscape, influencing the balance of power and the trajectory of national policy-making.\n\n### NDA’s Decisive Win in Bihar: Cementing BJP’s National Strength\n\nThe National Democratic Alliance (NDA), led by the Bharatiya Janata Party (BJP), secured a decisive victory in Bihar's state elections. This result reinforced BJP's dominant position in one of India's most politically significant states, characterized by a large voter base and strategic location. The win consolidates the NDA’s grassroots organizational strength and sends a strong signal about BJP’s enduring appeal in regional politics, boosting its mandate ahead of subsequent national elections. This victory also strengthens BJP's capacity to mobilize rural and caste-based vote banks—a crucial factor in Indian electoral politics ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises)).\n\n### BJP’s Return to Power in Delhi after Decades: Factors Behind the Shift\n\nIn Delhi, the BJP made a remarkable comeback after nearly 30 years, ending a long period of dominance by the Aam Aadmi Party (AAP). Key factors propelling this shift included effective campaigning focused on national security, economic development promises, and voter outreach to middle-class urban populations. Additionally, the BJP leveraged growing dissatisfaction with local governance on issues like public services and infrastructure. This shift highlights BJP’s strategic recalibration to urban electorates and suggests potential implications for governance models that blend local and central priorities ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\n### Historic Elections in Jammu & Kashmir: Voter Participation and Political Context\n\nThe 2024 Jammu & Kashmir elections marked a historic milestone, being the first comprehensive democratic exercise in the region since the revocation of its special status in 2019. Voter turnout was notably high despite security concerns and regional unrest, reflecting a strong desire among residents for political representation and inclusion in the Indian democratic process. These elections introduced new political dynamics, with traditional parties and newcomers competing in a reshaped governance framework under direct central administration. The results have significant implications for peacebuilding, regional autonomy debates, and the integration of Jammu & Kashmir into national political discourse ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).\n\n### Impact of State Elections on Coalition-Building and National Policy Directions\n\nState elections remain critical to coalition-building at the national level, especially in India’s multiparty landscape. Victories in states like Bihar and Jammu & Kashmir enhance BJP’s bargaining power within alliances, affecting the composition and stability of government coalitions. This, in turn, influences policymaking priorities such as federal resource allocation, social welfare schemes, and security policies. State governments aligned with the Centre facilitate smoother policy implementation, whereas opposition-led states may catalyze political contestation and negotiation, shaping the legislative agenda and balancing central-state relations ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)).\n\n### Electoral Reforms: Voter List Revisions Enhancing Legitimacy\n\nTo ensure the integrity of these critical elections, the Election Commission of India undertook extensive voter list revisions, targeting bogus entries and duplications. These reforms aimed to enhance electoral legitimacy by improving accuracy in voter rolls, thereby preventing electoral fra ...
#   (3,
#    '## Economic and Social Issues Influencing the 2024 Elections\n\nEconomic conditions were a pivotal factor shaping voter behavior and campaign strategies in India’s 2024 general elections. Unemployment and inflation emerged as primary concerns for a broad spectrum of voters, significantly affecting party support. According to several analyses, rising inflation, especially in food and fuel prices, eroded disposable incomes and deepened economic anxieties among urban and rural populations alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)). High unemployment rates, particularly among youth, added to voter dissatisfaction, partially explaining the erosion of support for incumbent parties in key constituencies.\n\nWhile Hindu nationalism continued to shape the political discourse, its mass appeal encountered limits amid pressing economic grievances. Voters increasingly prioritized livelihood, job security, and price stability over identity-based narratives. Reports suggest that parties leveraging Hindu nationalist themes faced challenges expanding their vote base in economically distressed regions where immediate material concerns took precedence ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)). This dynamic forced parties, especially the ruling coalition, to recalibrate their messaging to foreground economic promises.\n\nInterestingly, despite India maintaining steady GDP growth figures—hovering around 6-7% annually—the disconnect between macroeconomic growth and public satisfaction was stark. Many voters perceived growth as uneven, with benefits concentrated in specific sectors and urban centers, failing to translate into widespread economic upliftment. This disparity shaped political messaging, as opposition groups highlighted the contrast between official data and ground realities, framing themselves as champions of equitable development ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).\n\nMajor parties adopted nuanced campaign strategies to address these intertwined economic and social issues. The ruling party emphasized infrastructural development and job creation schemes, attempting to assuage economic anxieties while maintaining its cultural-nationalist base. Simultaneously, opposition coalitions centered their campaigns on anti-inflation rhetoric, rural distress, and inclusive welfare policies, seeking to capitalize on the electorate’s economic frustrations. Digital outreach and grassroots mobilization were key tools deployed to articulate these contrasting narratives effectively across diverse demographics ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises)).\n\nRegionally, economic concerns showed marked disparities reflected in the election outcomes. States with higher unemployment and inflation levels experienced stronger swings against the ruling party, evidencing a direct correlation between local economic stress and electoral volatility. For example, eastern and central states with agrarian distress and industrial slowdowns witnessed gains for opposition parties, whereas southern and western states, benefitting from relatively robust industrial growth and urban employment, displayed more stable incumbent support ([Source](https://politypolicy.substack.com/p/india-this-year-25-events-that-shaped)). This regional variation underscored the complexity of economic issues influencing voter choices beyond national-level narratives.\n\nIn summary, economic hardships around unemployment and inflation played a decisive role in shaping voter behavior by limiting the scope of identity-focused appeals, engendering skepticism about macroeconomic growth figures, and compelling parties to adopt more economically grounded campaign strategies. The resulting electoral landscape highlighted the critical importance of addressing t ...
#   (4,
#    '## International Relations and Diplomatic Tensions Affecting Indian Politics\n\nIn 2024, India’s international relations witnessed heightened diplomatic tensions, particularly with Canada and the United States, revolving around allegations linked to assassinations of Sikh separatist leaders. These accusations triggered a notable diplomatic fallout, straining ties with both countries. India accused some elements within the Sikh diaspora in Canada and the US of harboring separatist sympathies and facilitating anti-India activities, leading to formal protests and demand for tighter surveillance on these communities. This diplomatic row unfolded amid growing concerns over national security and sovereignty, gaining substantial attention in India’s domestic political discourse ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).\n\nPolitical parties leveraged these tensions strategically during the 2024 electoral campaigns. The ruling party framed the issue as a question of India’s international stature and territorial integrity, appealing to nationalist sentiments. Opposition groups criticized the government for diplomatic mismanagement and called for balanced foreign policies that safeguard Indian interests without isolating global partners. This narrative became a polarizing theme in public debates and rallies, often influencing voter perceptions on governance and diplomatic efficacy ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nTrade agreements and international cooperation prospects were also impacted. Uncertainty surrounding diplomatic relations raised concerns about potential delays or renegotiations of ongoing trade talks with the US and Canada, two significant economic partners for India. Business sectors expressed apprehension about supply chain disruptions, tariff impositions, and visa regulations that could arise amid diplomatic friction. Consequently, policymakers have reported attempts to intensify backchannel communications to mitigate risks and safeguard critical economic ties while addressing security concerns ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)).\n\nPublic and media response within India was markedly attentive and often showed nationalistic leanings. News outlets prominently covered developments related to the diplomatic tensions, with editorials frequently urging a firm stance by the government. Social media trends reflected a mixture of support for sovereignty-focused policies and calls for diplomatic prudence. Several Indian diaspora groups staged demonstrations to both support and critique government responses, indicating the contentious nature of the issue among expatriate communities as well ([Source](https://www.thehindu.com/news/national/)).\n\nOverall, these international relations challenges had a pronounced impact on India’s political positioning in 2024. The government’s handling of foreign policy issues became a litmus test for its competency on the global stage, shaping narratives about India’s emerging role as a regional power. Additionally, the diplomatic tensions influenced coalition dynamics within Parliament and electoral outcomes by energizing voter bases around sovereignty and diplomatic assertiveness. These events underscored how interconnected security concerns, international diplomacy, and domestic political agendas are in contemporary Indian politics ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).'),
#   (5,
#    '## Key Incidents and Political Events Beyond Elections\n\nThe political landscape in India in 2024 was shaped not only by the general elections but also by several major developments inside and outside Parliament, impacting governance and political discourse significantly.\n\n### Parliamentary Dynamics and Modi’s Rajya Sabha Address\n\nPost-elections, the Lok Sabha sessions experienced visible disruptions with opposition parties raising strong objections over policy priorities and governance issues. These interruptions reflected intense political rivalry and challenges in passing key legislations. Prime Minister Narendra Modi’s address to the Rajya Sabha was a crucial moment, where he outlined the government’s vision for the next five years, emphasizing economic growth, national security, and diplomatic priorities. His speech aimed to pacify critics and assert a narrative of stability despite fragmented mandates in the Lok Sabha ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).\n\n### Resolution of the India-China Border Situation\n\nA significant diplomatic breakthrough occurred with India and China resolving key issues related to their contentious border areas. The de-escalation of military standoffs improved bilateral ties and reduced security anxieties. Politically, this resolution consolidated the incumbent government’s credibility in managing foreign affairs and national security, bolstering domestic support amidst global uncertainty. Analysts noted that stable India-China relations allowed policymakers to refocus on internal development agendas without the looming threat of border conflicts ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\n### Social and Political Protests Influencing Political Opinion\n\nThe year also saw widespread social and political protests concerning agrarian reforms, labor laws, and urban governance. These movements highlighted discontent in various segments of society and exerted pressure on both central and state governments to revisit contentious policies. The protests became a barometer of shifting political opinions, especially among youth and marginalized communities, signaling potential realignments ahead in party support bases. They underscored challenges in balancing economic reforms with social equity ([Source](https://m.economictimes.com/news/india/10-big-events-india-witnessed-in-2024/articleshow/116791761.cms)).\n\n### India’s T20 World Championship Victory as a National Unifier\n\nIn a contrasting but significant development, India’s triumph in the T20 World Cup emerged as a unifying event that momentarily transcended political divisions. The victory fostered a collective sense of national pride across diverse demographics. This sport achievement provided positive momentum for the government in managing public sentiment amid ongoing political debates and challenges. It demonstrated the power of national events in shaping political narratives beyond policy and elections ([Source](https://newsreel.asia/articles/10-key-events-that-shaped-india-in-2024)).\n\n### Contributions to Political Narratives and Governance Challenges\n\nTogether, these events influenced the political discourse and governance framework in 2024:\n\n- Parliamentary obstructions and Modi’s assertive Rajya Sabha address highlighted uncertainties in legislative functioning and the need for coalition-building.  \n- Resolution with China reinforced national security narratives and enabled policy focus shifts.  \n- Social unrest revealed fractures in public consensus, alerting policymakers to socio-economic grievances.  \n- Sports success offered a critical soft power lever to unite the populace amid political fragmentation.\n\nIn sum, these key incidents exemplified the complex interplay of diplomacy, domestic policy, social movements, and symbolic victories shaping India’s governance and political narratives through 2024 ([Sour ...
#   (6,
#    "## Emerging Political Alliances and Opposition Realignments\n\nThe 2024 Indian general elections have catalyzed significant shifts in political alliances and opposition strategies, reshaping the landscape of competition and governance prospects in India.\n\n### The Indian National Developmental Inclusive Alliance (INDIA Alliance)\n\nFormed as a broad coalition of opposition parties, the Indian National Developmental Inclusive Alliance (INDIA alliance) emerged to consolidate dissent against the ruling Bharatiya Janata Party (BJP). Member parties include the Indian National Congress, Trinamool Congress, Nationalist Congress Party, and several regional players aiming to pool resources and voter bases to improve electoral performance.\n\nDespite varied success across states, the alliance succeeded in winning notable seats, impacting the electoral arithmetic substantially. It demonstrated the potential strength of strategic coalition-building but also revealed cracks due to ideological heterogeneity and regional leadership ambitions ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)). \n\n### BJP’s Internal Reorganization\n\nParallelly, the BJP undertook strategic internal reorganization under the leadership of Prime Minister Narendra Modi and party strategist Amit Shah. This reorganization reinforced centralized control mechanisms, streamlined candidate selections, and tightened party discipline, which enhanced organizational coherence and electoral machinery efficiency ([Source](https://www.thehindu.com/news/national/)).\n\nThe consolidation within BJP helped it navigate challenges posed by increasingly coordinated opposition efforts and maintain a dominant position in several key states.\n\n### Opposition Fragmentation and Realignment Challenges\n\nHowever, the opposition alliance faces inherent challenges related to fragmentation and realignment. Deep-rooted regional loyalties, policy disagreements, and competition for leadership roles continue to hamper a fully unified front. Post-election, several regional parties reassessed their alignments, leading to shifting blocs and tactical realignments that could complicate collaborative governance plans ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).\n\nThese challenges underscore the complexity of alliance politics in India's multifaceted political environment and suggest that cohesion remains a key obstacle for opposition effectiveness.\n\n### Election Allegations and Political Stability\n\nThe 2024 elections were also marked by allegations ranging from vote theft claims to manipulation of electronic voting machines, creating tensions that permeated both pre- and post-election phases. Such disputes have unsettled political stability, provoking public distrust in the electoral process. While investigative bodies and courts have intervened, the controversies have strained inter-party relations and complicated policy consensus-building ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).\n\nEffective resolution mechanisms and transparency enhancements remain critical to restoring electoral integrity and political stability moving forward.\n\n### Reshaping Political Competition and Governance Prospects\n\nThe evolving alliances have fundamentally reshaped the dynamics of political competition. The INDIA alliance signals a shift toward multi-polar contestation, moving away from BJP’s erstwhile electoral dominance. This has introduced greater uncertainty, requiring new governance coalitions that must balance ideological diversity and regional interests.\n\nThe future governance landscape will likely feature more negotiated settlements and coalition accommodations, challenging the traditional single-party majority model that defined previous BJP administrations. For developers and technical professionals analyzing political trends, these developments highlight the increasin ...
#   (1,
#    "## Overview of the 2024 Indian General Elections\n\nThe 2024 Lok Sabha elections were among the largest democratic exercises globally, marked by record voter engagement and intense political competition. Voting took place in multiple phases from April through early June, culminating in a historic turnout of approximately 67.4%, the highest in two decades. This surge in voter participation underscored the electorate's keen interest and reflected heightened political mobilization across urban and rural constituencies alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nThe Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) emerged as the single largest coalition but fell short of securing an outright majority in the 543-seat Lok Sabha, winning around 235 seats—significantly less than the 272 needed to form the government independently. This marked a departure from previous elections where the NDA had achieved a comfortable majority. The BJP’s reduced seat count indicated voter recalibration and vibrant competition from opposition fronts ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).\n\nRegionally, election outcomes revealed varied political dynamics. The BJP saw declines in several key states, losing ground in southern and eastern regions where regional parties and opposition alliances made substantial gains. The Indian National Congress, though still recovering from earlier setbacks, improved its tally modestly, bucking a trend of steady decline. The Aam Aadmi Party (AAP) expanded its footprint beyond Delhi, notably gaining seats in Punjab and parts of the northeast, signaling a shift toward issue-based regional politics. Additionally, regional parties such as the Trinamool Congress in West Bengal and the Dravida Munnetra Kazhagam (DMK) in Tamil Nadu consolidated their power bases, reflecting the electorate's growing preference for localized governance ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises), [Source](https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray)).\n\nVoter concerns that shaped the election results mainly revolved around unemployment, inflation, and infrastructural development. Rising joblessness among youth and persistent inflation stressed economic challenges, while infrastructure deficits in health, education, and rural development influenced voting patterns. Environmental issues and governance transparency also emerged as secondary yet notable factors. These priorities illustrated a nuanced electorate increasingly demanding tangible improvements alongside ideological allegiance ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).\n\nThe election results immediately altered the political landscape. The absence of a clear mandate for the NDA necessitates coalition-building and pragmatic alliances, potentially fostering a more consensus-driven legislative approach. Opposition gains bolstered their voice, setting the stage for stronger parliamentary scrutiny. The diversification of party representation is likely to drive multipolar policy debate, affecting legislation on economic reform, social welfare, and foreign relations. For developers and analysts, these shifts suggest an evolving regulatory environment with potential impacts on technology investments, digital infrastructure policies, and innovation incentives ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nIn conclusion, the 2024 Indian general elections represent a critical juncture, marked by increased voter participation, a more fragmented parliamentary outcome, and clear signals of changing public expectations. The emerging pluralistic political scenario promises a period of dynamic policy formulation and governance adjustment with broad implic ...
#   (2,
# ...
#  'merged_md': "# Key Developments Shaping Indian Politics in 2024\n\n## Overview of the 2024 Indian General Elections\n\nThe 2024 Lok Sabha elections were among the largest democratic exercises globally, marked by record voter engagement and intense political competition. Voting took place in multiple phases from April through early June, culminating in a historic turnout of approximately 67.4%, the highest in two decades. This surge in voter participation underscored the electorate's keen interest and reflected heightened political mobilization across urban and rural constituencies alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nThe Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) emerged as the single largest coalition but fell short of securing an outright majority in the 543-seat Lok Sabha, winning around 235 seats—significantly less than the 272 needed to form the government independently. This marked a departure from previous elections where the NDA had achieved a comfortable majority. The BJP’s reduced seat count indicated voter recalibration and vibrant competition from opposition fronts ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).\n\nRegionally, election outcomes revealed varied political dynamics. The BJP saw declines in several key states, losing ground in southern and eastern regions where regional parties and opposition alliances made substantial gains. The Indian National Congress, though still recovering from earlier setbacks, improved its tally modestly, bucking a trend of steady decline. The Aam Aadmi Party (AAP) expanded its footprint beyond Delhi, notably gaining seats in Punjab and parts of the northeast, signaling a shift toward issue-based regional politics. Additionally, regional parties such as the Trinamool Congress in West Bengal and the Dravida Munnetra Kazhagam (DMK) in Tamil Nadu consolidated their power bases, reflecting the electorate's growing preference for localized governance ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises), [Source](https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray)).\n\nVoter concerns that shaped the election results mainly revolved around unemployment, inflation, and infrastructural development. Rising joblessness among youth and persistent inflation stressed economic challenges, while infrastructure deficits in health, education, and rural development influenced voting patterns. Environmental issues and governance transparency also emerged as secondary yet notable factors. These priorities illustrated a nuanced electorate increasingly demanding tangible improvements alongside ideological allegiance ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).\n\nThe election results immediately altered the political landscape. The absence of a clear mandate for the NDA necessitates coalition-building and pragmatic alliances, potentially fostering a more consensus-driven legislative approach. Opposition gains bolstered their voice, setting the stage for stronger parliamentary scrutiny. The diversification of party representation is likely to drive multipolar policy debate, affecting legislation on economic reform, social welfare, and foreign relations. For developers and analysts, these shifts suggest an evolving regulatory environment with potential impacts on technology investments, digital infrastructure policies, and innovation incentives ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nIn conclusion, the 2024 Indian general elections represent a critical juncture, marked by increased voter participation, a more fragmented parliamentary outcome, and clear signals of changing public expectations. The emerging pluralistic political scenario promises a period of dynam ...
#  'md_with_placeholders': "# Key Developments Shaping Indian Politics in 2024\n\n## Overview of the 2024 Indian General Elections\n\nThe 2024 Lok Sabha elections were among the largest democratic exercises globally, marked by record voter engagement and intense political competition. Voting took place in multiple phases from April through early June, culminating in a historic turnout of approximately 67.4%, the highest in two decades. This surge in voter participation underscored the electorate's keen interest and reflected heightened political mobilization across urban and rural constituencies alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nThe Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) emerged as the single largest coalition but fell short of securing an outright majority in the 543-seat Lok Sabha, winning around 235 seats\x1a significantly less than the 272 needed to form the government independently. This marked a departure from previous elections where the NDA had achieved a comfortable majority. The BJP\x039;s reduced seat count indicated voter recalibration and vibrant competition from opposition fronts ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).\n\nRegionally, election outcomes revealed varied political dynamics. The BJP saw declines in several key states, losing ground in southern and eastern regions where regional parties and opposition alliances made substantial gains. The Indian National Congress, though still recovering from earlier setbacks, improved its tally modestly, bucking a trend of steady decline. The Aam Aadmi Party (AAP) expanded its footprint beyond Delhi, notably gaining seats in Punjab and parts of the northeast, signaling a shift toward issue-based regional politics. Additionally, regional parties such as the Trinamool Congress in West Bengal and the Dravida Munnetra Kazhagam (DMK) in Tamil Nadu consolidated their power bases, reflecting the electorate\x039s growing preference for localized governance ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises), [Source](https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray)).\n\nVoter concerns that shaped the election results mainly revolved around unemployment, inflation, and infrastructural development. Rising joblessness among youth and persistent inflation stressed economic challenges, while infrastructure deficits in health, education, and rural development influenced voting patterns. Environmental issues and governance transparency also emerged as secondary yet notable factors. These priorities illustrated a nuanced electorate increasingly demanding tangible improvements alongside ideological allegiance ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).\n\nThe election results immediately altered the political landscape. The absence of a clear mandate for the NDA necessitates coalition-building and pragmatic alliances, potentially fostering a more consensus-driven legislative approach. Opposition gains bolstered their voice, setting the stage for stronger parliamentary scrutiny. The diversification of party representation is likely to drive multipolar policy debate, affecting legislation on economic reform, social welfare, and foreign relations. For developers and analysts, these shifts suggest an evolving regulatory environment with potential impacts on technology investments, digital infrastructure policies, and innovation incentives ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\n[[IMAGE_1]]\n\nIn conclusion, the 2024 Indian general elections represent a critical juncture, marked by increased voter participation, a more fragmented parliamentary outcome, and clear signals of changing public expectations. The emerging pluralistic politi ...
#  'image_specs': [{'placeholder': '[[IMAGE_1]]',
#    'filename': 'india_2024_election_map.png',
#    'alt': 'Map of India showing 2024 Lok Sabha election results by party and region',
#    'caption': '2024 Indian General Election Results by State and Major Parties',
#    'prompt': 'A detailed color-coded map of India showing the 2024 Lok Sabha election results by state and major political parties, highlighting BJP-led NDA seats, opposition alliances, and regional party strongholds, with clear labels and legend.',
#    'size': '1024x1024',
#    'quality': 'high'}],
#  'final': "# Key Developments Shaping Indian Politics in 2024\n\n## Overview of the 2024 Indian General Elections\n\nThe 2024 Lok Sabha elections were among the largest democratic exercises globally, marked by record voter engagement and intense political competition. Voting took place in multiple phases from April through early June, culminating in a historic turnout of approximately 67.4%, the highest in two decades. This surge in voter participation underscored the electorate's keen interest and reflected heightened political mobilization across urban and rural constituencies alike ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\nThe Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) emerged as the single largest coalition but fell short of securing an outright majority in the 543-seat Lok Sabha, winning around 235 seats\x1a significantly less than the 272 needed to form the government independently. This marked a departure from previous elections where the NDA had achieved a comfortable majority. The BJP\x039;s reduced seat count indicated voter recalibration and vibrant competition from opposition fronts ([Source](https://www.bbc.com/news/articles/c977g8gl5q2o)).\n\nRegionally, election outcomes revealed varied political dynamics. The BJP saw declines in several key states, losing ground in southern and eastern regions where regional parties and opposition alliances made substantial gains. The Indian National Congress, though still recovering from earlier setbacks, improved its tally modestly, bucking a trend of steady decline. The Aam Aadmi Party (AAP) expanded its footprint beyond Delhi, notably gaining seats in Punjab and parts of the northeast, signaling a shift toward issue-based regional politics. Additionally, regional parties such as the Trinamool Congress in West Bengal and the Dravida Munnetra Kazhagam (DMK) in Tamil Nadu consolidated their power bases, reflecting the electorate\x039s growing preference for localized governance ([Source](https://www.aljazeera.com/news/2024/6/4/india-election-results-big-wins-losses-and-surprises), [Source](https://www.aljazeera.com/news/2024/4/16/india-election-2024-which-are-the-main-political-parties-in-the-fray)).\n\nVoter concerns that shaped the election results mainly revolved around unemployment, inflation, and infrastructural development. Rising joblessness among youth and persistent inflation stressed economic challenges, while infrastructure deficits in health, education, and rural development influenced voting patterns. Environmental issues and governance transparency also emerged as secondary yet notable factors. These priorities illustrated a nuanced electorate increasingly demanding tangible improvements alongside ideological allegiance ([Source](https://apnews.com/article/india-election-modi-bjp-congress-510eea0717dec60c10ddc510d82b1ccd)).\n\nThe election results immediately altered the political landscape. The absence of a clear mandate for the NDA necessitates coalition-building and pragmatic alliances, potentially fostering a more consensus-driven legislative approach. Opposition gains bolstered their voice, setting the stage for stronger parliamentary scrutiny. The diversification of party representation is likely to drive multipolar policy debate, affecting legislation on economic reform, social welfare, and foreign relations. For developers and analysts, these shifts suggest an evolving regulatory environment with potential impacts on technology investments, digital infrastructure policies, and innovation incentives ([Source](https://eu.boell.org/en/2024/06/07/2024-indian-election-new-political-landscape-unfolds)).\n\n> **[IMAGE GENERATION FAILED]** 2024 Indian General Election Results by State and Major Parties\n>\n> **Alt:** Map of India showing 2024 Lok Sabha election results by party and region\n>\n> **Prompt:** A detailed color-coded map of India showing the 2024 Lok Sabha election  ...

# %%
g = StateGraph(State)
g.add_node("Dispatcher", router_node)
g.add_node("Explorer", research_node)
g.add_node("Controller", orchestrator_node)
g.add_node("Processor", worker_node)
g.add_node("Assembler", reducer_subgraph)

g.add_edge(START, "Dispatcher")
g.add_conditional_edges("Dispatcher", route_next, {"Explorer": "Explorer", "Controller": "Controller"})
g.add_edge("Explorer", "Controller")

g.add_conditional_edges("Controller", fanout, ["Processor"])
g.add_edge("Processor", "Assembler")
g.add_edge("Assembler", END)

workflow = g.compile()
workflow
